# %% [markdown]
# ## Waveform Viewer — Arrhythmia Label Verification
#
# Edit **Cell 1** (case ID and time window), then run **Cell 2** to plot.
#
# **What you will see:**
# - **ECG trace** (Lead II if available, V5 otherwise) with coloured vertical markers per beat type
# - **Orange shading** = arrhythmia episodes detected by our pipeline
# - **Rhythm label text** at every rhythm change point
# - **SpO2 panel** below for context (dashed lines at 95% and 90%)
#
# **Beat type colour key:** Gray = Normal (N) · Blue = Supraventricular (S) · Red = Ventricular (V) · Purple = Unclassifiable (U)

# %%
# EDIT THESE VALUES THEN RUN THE NEXT CELL

CASE_ID   = 581  # VitalDB case ID to inspect
START_SEC = 9687.397222222222 # window start (seconds from recording start)
END_SEC   = 9708.980555555556     # window end   (seconds from recording start)

# %%
import os
BASE_DIR = os.path.abspath(os.path.join('..', '..'))   # notebooks/eda/ -> repo root
ANNOT_DIR    = os.path.join(BASE_DIR, 'external_data', 'vitaldb-arrhythmia-database-1.0.0', 'Annotation_Files')
EPISODES_CSV = os.path.join(BASE_DIR, 'data', 'processed', 'arrhythmia_episodes_updated.csv')
